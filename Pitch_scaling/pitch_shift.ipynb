# %%
import matplotlib.pyplot as plt
import numpy as np
import librosa
import librosa.display
import soundfile as sf
import os
import pyrubberband.pyrb as pypb
from scipy.io.wavfile import read
import torch
import random

from numpy.fft import fft, ifft

# %%
y, sr = librosa.load("E:/datasets/project3/AISHELL-3/train/wav/SSB0011/SSB00110008.wav", sr=22050)

def pitch_shifting(x, sr, n_steps, bins_per_octave=12):
    # sr: 音频采样率
    # n_steps: 要移动多少步
    # bins_per_octave: 每个八度音阶(半音)多少步
    return librosa.effects.pitch_shift(x, sr, n_steps, bins_per_octave=bins_per_octave)

# %%
wav, sr_org = librosa.load('E:/datasets/project3/recover/SSB00050008_0.0_.wav', sr=22050)
# sf.write('E:/datasets/project3/AISHELL-3/scaled/1.wav', wav, 22050)

# %%
figsize = (12, 8)
figure, ax = plt.subplots(dpi=1000,figsize=figsize)
plt.plot(wav)
plt.ylim(-0.3, 0.3)
# plt.axis('off')
plt.savefig('./org_speech.pdf')

# %%
wav, sr_org = librosa.load('E:/datasets/project3/recover/SSB00050008_7.648_.wav', sr=22050)
# sf.write('E:/datasets/project3/AISHELL-3/scaled/1.wav', wav, 22050)

# %%
figsize = (12, 8)
figure, ax = plt.subplots(dpi=1000,figsize=figsize)
plt.plot(wav)
plt.ylim(-0.3, 0.3)
# plt.axis('off')
plt.savefig('./scaled_speech.pdf')

# %%
wav, sr_org = librosa.load('E:/datasets/project3/recover/SSB00050008_recover1.wav', sr=22050)
# sf.write('E:/datasets/project3/AISHELL-3/scaled/1.wav', wav, 22050)

# %%
figsize = (12, 8)
figure, ax = plt.subplots(dpi=1000,figsize=figsize)
plt.plot(wav)
plt.ylim(-0.3, 0.3)
# plt.axis('off')
plt.savefig('./recover1.pdf')

# %%
wav, sr_org = librosa.load('E:/datasets/project3/recover/SSB00050008_recover2.wav', sr=22050)
# sf.write('E:/datasets/project3/AISHELL-3/scaled/1.wav', wav, 22050)

# %%
figsize = (12, 8)
figure, ax = plt.subplots(dpi=1000,figsize=figsize)
plt.plot(wav)
plt.ylim(-0.3, 0.3)
# plt.axis('off')
plt.savefig('./recover2.pdf')

# %%
wav, sr_org = librosa.load('E:/datasets/project3/recover/SSB00050001_recover1.wav', sr=22050)
# sf.write('E:/datasets/project3/AISHELL-3/scaled/1.wav', wav, 22050)

# %%
plt.plot(wav)

# %%
plt.plot(wav)

# %%
sr_org
# Out:
# 22050

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
file_path = 'E:/datasets/project3/AISHELL-3/test/wav/SSB1872/'
file_list_spk1 = os.listdir(file_path)

# %%
file_path = 'E:/datasets/project3/recover/'
file_list_spk1 = os.listdir(file_path)

# %%
file_path_r = 'E:/datasets/project3/AISHELL-3/test/wav/SSB0139/'
file_list_spk1_r = os.listdir(file_path_r)

# %%
file_list_spk1[3]
# Out:
# 'SSB18720002_3.992.wav'

# %% [markdown]
# #### 最少移动2个半音，不能到12个

# %%
np.random.shuffle(file_list_spk1)

# %%
len(file_list_spk1)
# Out:
# 13100

# %%
str(file_list_spk1[0].split('.')[0]+"_f1")
# Out:
# 'LJ050-0103_f1'

# %%
len(file_list_spk1)
# Out:
# 13100

# %%
12*np.log2(0.6)
# Out:
# -8.843587129994475

# %%
wav, _ = librosa.load(file_path+file_list_spk1[3], sr=22050)

# %%
wav.shape
# Out:
# (104256,)

# %%
wav, sr1 = librosa.load('E:/datasets/project3/AISHELL-3/test/wav/SSB1902/SSB19020043.wav', sr=22050)
# wav = librosa.effects.pitch_shift(wav, sr=sr1, n_steps=7.332, bins_per_octave=12)
sf.write('E:/datasets/project3/recover/SSB19020043.wav', wav, sr1)

# %%
wav, sr1 = librosa.load('E:/datasets/project3/AISHELL-3/unseen_generlization/7.0/SSB06930023.wav', sr=22050)
wav = librosa.effects.pitch_shift(wav, sr=sr1, n_steps=7.0, bins_per_octave=12)
sf.write('E:/datasets/project3/recover/SSB06930023_7.wav', wav, sr1)

# %%
wav, sr1 = librosa.load('E:/datasets/project3/recover/a3.wav', sr=22050)
# wav = librosa.effects.pitch_shift(wav, sr=sr1, n_steps=5.47, bins_per_octave=12)
sf.write('E:/datasets/project3/recover/a3_resample.wav', wav, sr1)

# %%
wav, sr1 = librosa.load(file_path+file_list_spk1[5], sr=22050)
wav = librosa.effects.pitch_shift(wav, sr=sr1, n_steps=-3.12, bins_per_octave=12)
# wav_list_spk1_4.append(wav)
# sf.write('E:/datasets/project3/recover/'+str(file_list_spk1[-6].split('_')[0]+'_3.82')+'.wav', wav, sr1)
sf.write(file_path+str(file_list_spk1[5].split('_')[0]+'_rec')+'.wav', wav, sr1)

# %%
wav, _ = librosa.load('E:/datasets/project3/LJSpeech-1.1/test/LJ016-0109_fn6.5.wav', sr=22050)
sf.write('E:/datasets/project3/LJSpeech-1.1/test/LJ016-0109_fn6.5'+"_t0.65"+'.wav', wav, int(22050*0.65))

# %%
wav, sr = librosa.load(file_path_r + file_list_spk1_r[0])
wav = librosa.effects.pitch_shift(wav, sr=sr, n_steps=-7, bins_per_octave=12)
# wav_list_spk1_4.append(wav)
sf.write(file_path_r+str(file_list_spk1_r[0].split('.')[0]+"_f4.2")+'.wav', wav, sr)

# %%
E:\datasets\project3\LJSpeech-1.1\test

# %%
file_path = 'E:/datasets/project3/LJSpeech-1.1/wavs/'
for i in range(818): #590
        wav, _ = librosa.load(file_path+file_list_spk1[i], sr=22050)
        wav = librosa.effects.pitch_shift(wav, sr=22050, n_steps=1, bins_per_octave=12)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/only_freq_scaled/wav_f1/'+str(file_list_spk1[i].split('.')[0]+"_f1")+'.wav', wav, 22050)
        
for i in range(818):
        wav, _ = librosa.load(file_path+file_list_spk1[i+818], sr=22050)
        wav = librosa.effects.pitch_shift(wav, sr=22050, n_steps=2, bins_per_octave=12)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/only_freq_scaled/wav_f2/'+str(file_list_spk1[i+818].split('.')[0]+"_f2")+'.wav', wav, 22050)    
    
for i in range(818):
        wav, _ = librosa.load(file_path+file_list_spk1[i+2454], sr=22050)
        wav = librosa.effects.pitch_shift(wav, sr=22050, n_steps=3, bins_per_octave=12)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/only_freq_scaled/wav_f3/'+str(file_list_spk1[i+2454].split('.')[0]+"_f3")+'.wav', wav, 22050)
        
for i in range(818):
        wav, _ = librosa.load(file_path+file_list_spk1[i+3272], sr=22050)
        wav = librosa.effects.pitch_shift(wav, sr=22050, n_steps=4, bins_per_octave=12)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/only_freq_scaled/wav_f4/'+str(file_list_spk1[i+3272].split('.')[0]+"_f4")+'.wav', wav, 22050)    
            
for i in range(818):
        wav, _ = librosa.load(file_path+file_list_spk1[i+4090], sr=22050)
        wav = librosa.effects.pitch_shift(wav, sr=22050, n_steps=5, bins_per_octave=12)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/only_freq_scaled/wav_f5/'+str(file_list_spk1[i+4090].split('.')[0]+"_f5")+'.wav', wav, 22050)    
        
for i in range(818):
        wav, _ = librosa.load(file_path+file_list_spk1[i+4908], sr=22050)
        wav = librosa.effects.pitch_shift(wav, sr=22050, n_steps=6, bins_per_octave=12)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/only_freq_scaled/wav_f6/'+str(file_list_spk1[i+4908].split('.')[0]+"_f6")+'.wav', wav, 22050)
        
for i in range(818):
        wav, _ = librosa.load(file_path+file_list_spk1[i+5726], sr=22050)
        wav = librosa.effects.pitch_shift(wav, sr=22050, n_steps=7, bins_per_octave=12)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/only_freq_scaled/wav_f7/'+str(file_list_spk1[i+5726].split('.')[0]+"_f7")+'.wav', wav, 22050)
        
for i in range(818):
        wav, _ = librosa.load(file_path+file_list_spk1[i+6544], sr=22050)
        wav = librosa.effects.pitch_shift(wav, sr=22050, n_steps=8, bins_per_octave=12)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/only_freq_scaled/wav_f8/'+str(file_list_spk1[i+6544].split('.')[0]+"_f8")+'.wav', wav, 22050)
        
for i in range(818):
        wav, _ = librosa.load(file_path+file_list_spk1[i+7362], sr=22050)
        wav = librosa.effects.pitch_shift(wav, sr=22050, n_steps=-1, bins_per_octave=12)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/only_freq_scaled/wav_fn1/'+str(file_list_spk1[i+7362].split('.')[0]+"_fn1")+'.wav', wav, 22050)
        
for i in range(818):
        wav, _ = librosa.load(file_path+file_list_spk1[i+8180], sr=22050)
        wav = librosa.effects.pitch_shift(wav, sr=22050, n_steps=-2, bins_per_octave=12)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/only_freq_scaled/wav_fn2/'+str(file_list_spk1[i+8180].split('.')[0]+"_fn2")+'.wav', wav, 22050)    
         
for i in range(818):
        wav, _ = librosa.load(file_path+file_list_spk1[i+8998], sr=22050)
        wav = librosa.effects.pitch_shift(wav, sr=22050, n_steps=-3, bins_per_octave=12)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/only_freq_scaled/wav_fn3/'+str(file_list_spk1[i+8998].split('.')[0]+"_fn3")+'.wav', wav, 22050)
        
for i in range(818):
        wav, _ = librosa.load(file_path+file_list_spk1[i+9816], sr=22050)
        wav = librosa.effects.pitch_shift(wav, sr=22050, n_steps=-4, bins_per_octave=12)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/only_freq_scaled/wav_fn4/'+str(file_list_spk1[i+9816].split('.')[0]+"_fn4")+'.wav', wav, 22050)    
            
for i in range(818):
        wav, _ = librosa.load(file_path+file_list_spk1[i+10634], sr=22050)
        wav = librosa.effects.pitch_shift(wav, sr=22050, n_steps=-5, bins_per_octave=12)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/only_freq_scaled/wav_fn5/'+str(file_list_spk1[i+10634].split('.')[0]+"_fn5")+'.wav', wav, 22050)         

for i in range(818):
        wav, _ = librosa.load(file_path+file_list_spk1[i+11452], sr=22050)
        wav = librosa.effects.pitch_shift(wav, sr=22050, n_steps=-6, bins_per_octave=12)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/only_freq_scaled/wav_fn6/'+str(file_list_spk1[i+11452].split('.')[0]+"_fn6")+'.wav', wav, 22050)
        
for i in range(818):
        wav, _ = librosa.load(file_path+file_list_spk1[i+12270], sr=22050)
        wav = librosa.effects.pitch_shift(wav, sr=22050, n_steps=-7, bins_per_octave=12)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/only_freq_scaled/wav_fn7/'+str(file_list_spk1[i+12270].split('.')[0]+"_fn7")+'.wav', wav, 22050)
        
for i in range(818):
        wav, _ = librosa.load(file_path+file_list_spk1[i+1636], sr=22050)
        wav = librosa.effects.pitch_shift(wav, sr=22050, n_steps=-8, bins_per_octave=12)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/only_freq_scaled/wav_fn8/'+str(file_list_spk1[i+1636].split('.')[0]+"_fn8")+'.wav', wav, 22050)
                 
        
# for i in range(590):
#         wav, _ = librosa.load(file_path+file_list_spk1[i+9440], sr=22050)
#         sf.write('E:/datasets/project3/LJSpeech-1.1/scaled/wav_t0.5/'+str(file_list_spk1[i+9440].split('.')[0]+"_t0.5")+'.wav', wav, int(22050*0.5))    
         
# for i in range(590):
#         wav, _ = librosa.load(file_path+file_list_spk1[i+10030], sr=22050)
#         # wav_list_spk1_4.append(wav)
#         sf.write('E:/datasets/project3/LJSpeech-1.1/scaled/wav_t0.7/'+str(file_list_spk1[i+10030].split('.')[0]+"_t0.7")+'.wav', wav, int(22050*0.7))
        
# for i in range(590):
#         wav, _ = librosa.load(file_path+file_list_spk1[i+10620], sr=22050)
#         # wav_list_spk1_4.append(wav)
#         sf.write('E:/datasets/project3/LJSpeech-1.1/scaled/wav_t0.9/'+str(file_list_spk1[i+10620].split('.')[0]+"_t0.9")+'.wav', wav, int(22050*0.9))    
            
# for i in range(590):
#         wav, _ = librosa.load(file_path+file_list_spk1[i+11210], sr=22050)
#         # wav_list_spk1_4.append(wav)
#         sf.write('E:/datasets/project3/LJSpeech-1.1/scaled/wav_t1.1/'+str(file_list_spk1[i+11210].split('.')[0]+"_t1.1")+'.wav', wav, int(22050*1.1))    
        
# for i in range(590):
#         wav, _ = librosa.load(file_path+file_list_spk1[i+11800], sr=22050)
#         # wav_list_spk1_4.append(wav)
#         sf.write('E:/datasets/project3/LJSpeech-1.1/scaled/wav_t1.3/'+str(file_list_spk1[i+11800].split('.')[0]+"_t1.3")+'.wav', wav, int(22050*1.3))

# for i in range(590):
#         wav, _ = librosa.load(file_path+file_list_spk1[i+12390], sr=22050)
#         # wav_list_spk1_4.append(wav)
#         sf.write('E:/datasets/project3/LJSpeech-1.1/scaled/wav_t1.5/'+str(file_list_spk1[i+12300].split('.')[0]+"_t1.5")+'.wav', wav, int(22050*1.5))

# %%
for i in range(590):
        wav, _ = librosa.load(file_path+file_list_spk1[i], sr=22050)
        sf.write('E:/datasets/project3/LJSpeech-1.1/scaled/wav_fn8_t0.5/'+str(file_list_spk1[i].split('.')[0]+"_t0.5")+'.wav', wav, int(22050*0.5))    
         
for i in range(590):
        wav, _ = librosa.load(file_path+file_list_spk1[i], sr=22050)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/scaled/wav_fn8_t0.7/'+str(file_list_spk1[i].split('.')[0]+"_t0.7")+'.wav', wav, int(22050*0.7))
        
for i in range(590):
        wav, _ = librosa.load(file_path+file_list_spk1[i], sr=22050)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/scaled/wav_fn8_t0.9/'+str(file_list_spk1[i].split('.')[0]+"_t0.9")+'.wav', wav, int(22050*0.9))    
            
for i in range(590):
        wav, _ = librosa.load(file_path+file_list_spk1[i], sr=22050)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/scaled/wav_fn8_t1.1/'+str(file_list_spk1[i].split('.')[0]+"_t1.1")+'.wav', wav, int(22050*1.1))    
        
for i in range(590):
        wav, _ = librosa.load(file_path+file_list_spk1[i], sr=22050)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/scaled/wav_fn8_t1.3/'+str(file_list_spk1[i].split('.')[0]+"_t1.3")+'.wav', wav, int(22050*1.3))

for i in range(590):
        wav, _ = librosa.load(file_path+file_list_spk1[i], sr=22050)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/scaled/wav_fn8_t1.5/'+str(file_list_spk1[i].split('.')[0]+"_t1.5")+'.wav', wav, int(22050*1.5))

# %%
for i in range(590):
        wav, _ = librosa.load(file_path+file_list_spk1[i], sr=22050)
        sf.write('E:/datasets/project3/LJSpeech-1.1/scaled/wav_f4_t0.5/'+str(file_list_spk1[i].split('.')[0]+"_t0.5")+'.wav', wav, int(22050*0.5))    
         
for i in range(590):
        wav, _ = librosa.load(file_path+file_list_spk1[i], sr=22050)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/scaled/wav_f4_t0.7/'+str(file_list_spk1[i].split('.')[0]+"_t0.7")+'.wav', wav, int(22050*0.7))
        
for i in range(590):
        wav, _ = librosa.load(file_path+file_list_spk1[i], sr=22050)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/scaled/wav_f4_t0.9/'+str(file_list_spk1[i].split('.')[0]+"_t0.9")+'.wav', wav, int(22050*0.9))    
            
for i in range(590):
        wav, _ = librosa.load(file_path+file_list_spk1[i], sr=22050)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/scaled/wav_f4_t1.1/'+str(file_list_spk1[i].split('.')[0]+"_t1.1")+'.wav', wav, int(22050*1.1))    
        
for i in range(590):
        wav, _ = librosa.load(file_path+file_list_spk1[i], sr=22050)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/scaled/wav_f4_t1.3/'+str(file_list_spk1[i].split('.')[0]+"_t1.3")+'.wav', wav, int(22050*1.3))

for i in range(590):
        wav, _ = librosa.load(file_path+file_list_spk1[i], sr=22050)
        # wav_list_spk1_4.append(wav)
        sf.write('E:/datasets/project3/LJSpeech-1.1/scaled/wav_f4_t1.5/'+str(file_list_spk1[i].split('.')[0]+"_t1.5")+'.wav', wav, int(22050*1.5))

# %%
file_list_spk1 = os.listdir('E:/datasets/project3/LJSpeech-1.1/wavs/.')

# %%
file_path = 'E:/datasets/project3/LJSpeech-1.1/wavs/'
wav_list_spk1_4 = []
for file in file_list_spk1:
    wav, _ = librosa.load(file_path+file, sr=22050)
    wav = librosa.effects.pitch_shift(wav, sr=22050, n_steps=-8, bins_per_octave=12)
    # wav_list_spk1_4.append(wav)
    sf.write('E:/datasets/project3/LJSpeech-1.1/wav_fn8/'+str(file)+'.wav', wav, 22050)

# %%
a = np.array([0.5,-2])

# %%
a
# Out:
# array([ 0.5, -2. ])

# %%
b = a*[12,2]

# %%
b
# Out:
# array([ 6., -4.])

# %%
np.random.uniform(low=0.5, high=2.0, size=None)
# Out:
# 1.9298150394213305

# %%
a=0+12*np.log2(0.5198150394213305)

# %%
a
# Out:
# -11.327156640629354

# %%
str(round(a,2))
# Out:
# '-11.33'

# %%
def load_wav_to_torch(full_path):
    """
    Loads wavdata into torch array
    """
    sampling_rate, data = read(full_path)
    return torch.from_numpy(data).float(), sampling_rate

# %%
def shift_pitch(signal, fs, f_ratio):
    """
    Calls psola pitch shifting algorithm
    :param signal: original signal in the time-domain
    :param fs: sample rate
    :param f_ratio: ratio by which the frequency will be shifted
    :return: pitch-shifted signal
    """
    peaks = find_peaks(signal, fs)
    new_signal = psola(signal, peaks, f_ratio)
    return new_signal


def find_peaks(signal, fs, max_hz=950, min_hz=75, analysis_win_ms=40, max_change=1.005, min_change=0.995):
    """
    Find sample indices of peaks in time-domain signal
    :param max_hz: maximum measured fundamental frequency
    :param min_hz: minimum measured fundamental frequency
    :param analysis_win_ms: window size used for autocorrelation analysis
    :param max_change: restrict periodicity to not increase by more than this ratio from the mean
    :param min_change: restrict periodicity to not decrease by more than this ratio from the mean
    :return: peak indices
    """
    N = len(signal)
    min_period = fs // max_hz
    max_period = fs // min_hz

    # compute pitch periodicity
    sequence = int(analysis_win_ms / 1000 * fs)  # analysis sequence length in samples
    periods = compute_periods_per_sequence(signal, sequence, min_period, max_period, N)

    # simple hack to avoid octave error: assume that the pitch should not vary much, restrict range
    mean_period = np.mean(periods)
    max_period = int(mean_period * 1.1)
    min_period = int(mean_period * 0.9)
    periods = compute_periods_per_sequence(signal, sequence, min_period, max_period, N)

    # find the peaks
    peaks = [np.argmax(signal[:int(periods[0]*1.1)])]
    while True:
        prev = peaks[-1]
        idx = prev // sequence  # current autocorrelation analysis window
        if prev + int(periods[idx] * max_change) >= N:
            break
        # find maximum near expected location
        peaks.append(prev + int(periods[idx] * min_change) +
                np.argmax(signal[prev + int(periods[idx] * min_change): prev + int(periods[idx] * max_change)]))
    return np.array(peaks)


def compute_periods_per_sequence(signal, sequence, min_period, max_period, N):
    """
    Computes periodicity of a time-domain signal using autocorrelation
    :param sequence: analysis window length in samples. Computes one periodicity value per window
    :param min_period: smallest allowed periodicity
    :param max_period: largest allowed periodicity
    :return: list of measured periods in windows across the signal
    """
    
    offset = 0  # current sample offset
    periods = []  # period length of each analysis sequence

    while offset < N:
        fourier = fft(signal[offset: offset + sequence])
        fourier[0] = 0  # remove DC component
        autoc = ifft(fourier * np.conj(fourier)).real
        autoc_peak = min_period + np.argmax(autoc[min_period: max_period])
        periods.append(autoc_peak)
        offset += sequence
    return periods


def psola(signal, peaks, f_ratio):
    """
    Time-Domain Pitch Synchronous Overlap and Add
    :param signal: original time-domain signal
    :param peaks: time-domain signal peak indices
    :param f_ratio: pitch shift ratio
    :return: pitch-shifted signal
    """
    N = len(signal)
    # Interpolate
    new_signal = np.zeros(N)
    new_peaks_ref = np.linspace(0, len(peaks) - 1, int(len(peaks) * f_ratio))
    new_peaks = np.zeros(len(new_peaks_ref)).astype(int)

    for i in range(len(new_peaks)):
        weight = new_peaks_ref[i] % 1
        left = np.floor(new_peaks_ref[i]).astype(int)
        right = np.ceil(new_peaks_ref[i]).astype(int)
        new_peaks[i] = int(peaks[left] * (1 - weight) + peaks[right] * weight)

    # PSOLA
    for j in range(len(new_peaks)):
        # find the corresponding old peak index
        i = np.argmin(np.abs(peaks - new_peaks[j]))
        # get the distances to adjacent peaks
        P1 = [new_peaks[j] if j == 0 else new_peaks[j] - new_peaks[j-1],
              N - 1 - new_peaks[j] if j == len(new_peaks) - 1 else new_peaks[j+1] - new_peaks[j]]
        # edge case truncation
        if peaks[i] - P1[0] < 0:
            P1[0] = peaks[i]
        if peaks[i] + P1[1] > N - 1:
            P1[1] = N - 1 - peaks[i]
        # linear OLA window
        window = list(np.linspace(0, 1, P1[0] + 1)[1:]) + list(np.linspace(1, 0, P1[1] + 1)[1:])
        # center window from original signal at the new peak
        new_signal[new_peaks[j] - P1[0]: new_peaks[j] + P1[1]] += window * signal[peaks[i] - P1[0]: peaks[i] + P1[1]]
    return new_signal

# %% [markdown]
# ### PhaseVocoder + Resample

# %%
file_path = 'E:/datasets/project3/AISHELL-1/wav/train'
spk_list = os.listdir(file_path)[47:178]
save_path = 'E:/datasets/project3/AISHELL-1/scaled178'
for spk_id in spk_list:
    file_list = os.listdir(os.path.join(file_path, spk_id))                   
    for file in file_list:
        #sample t and a
        try:
            for i in range(3):
                # t=np.random.uniform(low=0.5, high=2.0, size=None)
                s=np.random.uniform(low=-8.0, high=8.0, size=None)
                # a=s+12*np.log2(t)               
                # #guarantee a in [-8, 8]:               
                # while -8>a or a>8:
                #     t=np.random.uniform(low=0.5, high=2.0, size=None)
                #     s=np.random.uniform(low=-12.0, high=12.0, size=None)
                #     a=s+12*np.log2(t)  
   
                #scale pitch in both freq domian & time domain    
                wav, sr_org = librosa.load(os.path.join(file_path, spk_id, file), sr=22050)
                wav = librosa.effects.pitch_shift(wav, sr=22050, n_steps=s, bins_per_octave=12)
                           
                if not os.path.isdir(os.path.join(save_path, spk_id)):
                    os.makedirs(os.path.join(save_path, spk_id))  
                           
                sf.write(os.path.join(save_path, spk_id, file.split('.')[0]+'_'+str(round(s,3))+'_'+'.wav'), wav, 22050)
            
            
#         for i in range(1):
#             # t=np.random.uniform(low=0.5, high=2.0, size=None)
#             s=np.random.uniform(low=-8.0, high=8.0, size=None)
#             # a=s+12*np.log2(t)               
#             # #guarantee a in [-8, 8]:               
#             # while -8>a or a>8:
#             #     t=np.random.uniform(low=0.5, high=2.0, size=None)
#             #     s=np.random.uniform(low=-12.0, high=12.0, size=None)
#             #     a=s+12*np.log2(t)  
   
#             #scale pitch in both freq domian & time domain    
#             wav, sr_org = librosa.load(os.path.join(file_path, spk_id, file), sr=22050)
#             wav = pypb.pitch_shift(wav, sr=sr_org, n_steps=s)
                           
#             if not os.path.isdir(os.path.join(save_path, spk_id)):
#                 os.makedirs(os.path.join(save_path, spk_id))  
                           
#             sf.write(os.path.join(save_path, spk_id, file.split('.')[0]+'_'+str(round(s,2))+'_'+'.wav'), wav, sr_org)

            wav, sr_org = librosa.load(os.path.join(file_path, spk_id, file), sr=22050)
            sf.write(os.path.join(save_path, spk_id, file.split('.')[0]+'_'+str(0.00)+'_'+'.wav'), wav, 22050)
        except:
            pass
        # else:
        #     pass

# %% [markdown]
# ### TD-PSOLA

# %%
file_path = 'E:/datasets/project3/AISHELL-1/org'
spk_list = os.listdir(file_path)
save_path = 'E:/datasets/project3/AISHELL-3/scaled_psola'
for spk_id in spk_list[7:]:
    file_list = os.listdir(os.path.join(file_path, spk_id))                   
    for file in file_list:
        #sample a       
        for i in range(3):
            if not os.path.isdir(os.path.join(save_path, spk_id)):
                    os.makedirs(os.path.join(save_path, spk_id))  
                    
            try:
                s=np.random.uniform(low=-8.0, high=8.0, size=None)        
                wav, sr_org = librosa.load(os.path.join(file_path, spk_id, file), sr=22050)
                f_ratio = 2 ** (s / 12)
                wav = shift_pitch(wav, sr_org, f_ratio)        
                sf.write(os.path.join(save_path, spk_id, file.split('.')[0]+'_'+str(round(s,3))+'_'+'.wav'), wav, 22050)                
            except:
                pass
            
        wav, sr_org = librosa.load(os.path.join(file_path, spk_id, file), sr=22050)
        sf.write(os.path.join(save_path, spk_id, file.split('.')[0]+'_'+str(0.00)+'_'+'.wav'), wav, 22050)

# %%
file_path = 'E:/datasets/project3/AISHELL-3/train/wav'
spk_list = os.listdir(file_path)
save_path = 'E:/datasets/project3/AISHELL-3/org'
for spk_id in spk_list:
    file_list = os.listdir(os.path.join(file_path, spk_id))                   
    for file in file_list:                         
        if not os.path.isdir(os.path.join(save_path, spk_id)):
            os.makedirs(os.path.join(save_path, spk_id))  

        wav, sr_org = librosa.load(os.path.join(file_path, spk_id, file), sr=22050)
        sf.write(os.path.join(save_path, spk_id, file), wav, 22050)

# %%
str(0.00)
# Out:
# '0.0'

# %%
file_path = 'E:/datasets/project3/T_1_A'
spk_list = os.listdir(file_path)
save_path = 'E:/datasets/project3/T_1_scaled'
for spk_id in spk_list:
    file_list = os.listdir(os.path.join(file_path, spk_id))                   
    for file in file_list:
        #sample m
        m = -8
        for i in range(1):
            #scale pitch in both freq domian & time domain    
            wav, sr_org = librosa.load(os.path.join(file_path, spk_id, file), sr=22050)
            wav = librosa.effects.pitch_shift(wav, sr=sr_org, n_steps=m, bins_per_octave=12)
                        
            if not os.path.isdir(os.path.join(save_path, str(m))):
                os.makedirs(os.path.join(save_path, str(m)))  
                           
            sf.write(os.path.join(save_path, str(m), file), wav, sr_org)
            m+=1
            
            
        n = 4
        for i in range(5):
            #scale pitch in both freq domian & time domain    
            wav, sr_org = librosa.load(os.path.join(file_path, spk_id, file), sr=22050)
            wav = librosa.effects.pitch_shift(wav, sr=sr_org, n_steps=n, bins_per_octave=12)
                        
            if not os.path.isdir(os.path.join(save_path, str(n))):
                os.makedirs(os.path.join(save_path, str(n)))  
                           
            sf.write(os.path.join(save_path, str(n), file), wav, sr_org)
            n+=1
            
            
        if not os.path.isdir(os.path.join(save_path, '0')):
            os.makedirs(os.path.join(save_path, '0'))     
            
        sf.write(os.path.join(save_path, '0', file), wav, sr_org)
        
        # else:
        #     pass

# %%
i=0
file_path = 'E:/datasets/project3/AISHELL-3/train/wav'
spk_list = os.listdir(file_path)
for spk_id in spk_list:
    file_list = os.listdir(os.path.join(file_path, spk_id))                   
    for file in file_list:
        i+=1

# %%
i
# Out:
# 63262

# %% [markdown]
# ### Seen

# %%
file_path='E:/datasets/project3/AISHELL-3/test/wav/'
file_path2='E:/datasets/project3/AISHELL-3/scaled/'
save_path='E:/datasets/project3/AISHELL-3/seen/'

unseen_spklist = []
seen_spklist = os.listdir(file_path2)

for spk_id in os.listdir(file_path):
    if spk_id in seen_spklist:
        file_list = os.listdir(os.path.join(file_path, spk_id))
        for file in file_list:
            wav, sr1 = librosa.load(os.path.join(file_path, spk_id, file), sr=22050)
            if not os.path.isdir(os.path.join(save_path, spk_id)):
                os.makedirs(os.path.join(save_path, spk_id))  
            sf.write(os.path.join(save_path, spk_id, file), wav, sr1)
            
    else:
        pass

# %% [markdown]
# ### Unseen

# %%
file_path='E:/datasets/project3/AISHELL-1/wav/test/'
file_path2='E:/datasets/project3/AISHELL-1/wav/train/'
save_path='E:/datasets/project3/AISHELL-1/unseen/'

unseen_spklist = []
seen_spklist = os.listdir(file_path2)

for spk_id in os.listdir(file_path):
    if spk_id not in seen_spklist:
        file_list = os.listdir(os.path.join(file_path, spk_id))
        for file in file_list:
            if not os.path.isdir(os.path.join(save_path, spk_id)):
                    os.makedirs(os.path.join(save_path, spk_id)) 
            wav, _ = librosa.load(os.path.join(file_path, spk_id, file))
            if len(wav)<=16000:
                pass
            else:
                wav2, sr1 = librosa.load(os.path.join(file_path, spk_id, file), sr=22050)
                sf.write(os.path.join(save_path, spk_id, file), wav2, sr1)
            
    else:
        pass

# %% [markdown]
# ### Voxceleb

# %%
file_path = 'E:/datasets/project3/AISHELL-3/train/wav'
spk_list = os.listdir(file_path)
save_path = 'E:/datasets/project3/AISHELL-3/scaled'
for spk_id in spk_list:
    file_list = os.listdir(os.path.join(file_path, spk_id))                   
    for file in file_list:
        for wavs in file
            #sample t and a
            # t=np.random.uniform(low=0.5, high=2.0, size=None)
            s=np.random.uniform(low=-8.0, high=8.0, size=None)
            # a=s+12*np.log2(t)               
            # #guarantee a in [-8, 8]:               
            # while -8>a or a>8:
            #     t=np.random.uniform(low=0.5, high=2.0, size=None)
            #     s=np.random.uniform(low=-12.0, high=12.0, size=None)
            #     a=s+12*np.log2(t)  
   
            #scale pitch in both freq domian & time domain    
            wav, sr_org = librosa.load(os.path.join(file_path, spk_id, file), sr=22050)
            wav = librosa.effects.pitch_shift(wav, sr=22050, n_steps=s, bins_per_octave=12)
                           
            if not os.path.isdir(os.path.join(save_path, spk_id)):
                os.makedirs(os.path.join(save_path, spk_id))  
                           
            sf.write(os.path.join(save_path, spk_id, file.split('.')[0]+'_'+str(round(s,3))+'_'+'.wav'), wav, 22050)

            # else:
            #     pass

# %%
'''
将unseen文件夹中的所有音频放入一个list，进行分组，将等数量的音频存入变调系数命名的文件夹中
'''
'''
step 1: 获得file list
step 2: shuffle
step 3: 切片存入文件夹
'''
file_path = 'E:/datasets/project3/AISHELL-3/seen/'
save_path = 'E:/datasets/project3/AISHELL-3/seen_generlization/'
spk_list = os.listdir(file_path)
file_list = []
for spk_id in spk_list:
    for file in os.listdir(os.path.join(file_path, spk_id)):
        file_list.append(os.path.join(file_path, spk_id, file))
    
for file_name in file_list:
    if file_name.endswith(".wav"):
                        # 在屏幕上打印出来文件的名称 你得知道你删除了什么文件
        pass
    else:
        os.remove(file_name)

random.seed(1234)
random.shuffle(file_list)  
'''
按450一组切分
'''
m=0
a=-8
for i in range(33):
    for ele in file_list[m:m+335]:
        if not os.path.isdir(os.path.join(save_path, str(a))):
            os.makedirs(os.path.join(save_path, str(a)))  
            
        wav, sr = librosa.load(ele)
        sf.write(os.path.join(save_path, str(a), ele.split('\\')[-1]), wav, 22050)
    
    m+=335
    a+=0.5

# %%
len(file_list)
# Out:
# 15840

# %%
float(file_list[0].split('/')[-1].split('\\')[0])
# Out:
# -3.0
